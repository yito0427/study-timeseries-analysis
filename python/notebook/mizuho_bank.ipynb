# %% [markdown]
# # 時系列分析の書籍にしたがって、コードを生成していく
# データはp10にある、みずほ銀行の外国為替相場のヒストリカルデータ（月次）を利用する

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/mizuho_bank/m_quote.csv', skiprows=1)

# %%
df
# Out:
#      Unnamed: 0     USD     GBP     EUR    CAD     CHF    SEK    DKK    NOK  \
# 0     2002/4/30  131.15  189.01  115.97  82.83   79.13  12.73  15.61  15.20
# 1     2002/5/31  126.44  184.56  115.88  81.58   79.60  12.57  15.59  15.43
# 2     2002/6/28  123.53  183.00  117.83  80.64   80.09  12.94  15.86  15.92
# 3     2002/7/31  118.05  183.64  117.23  76.52   80.16  12.67  15.79  15.83
# 4     2002/8/30  119.08  183.14  116.45  75.85   79.60  12.59  15.69  15.68
# ..          ...     ...     ...     ...    ...     ...    ...    ...    ...
# 221   2020/9/30  105.76  137.30  124.70  80.07  115.59  11.97  16.76  11.60
# 222  2020/10/30  105.27  136.61  123.86  79.67  115.32  11.91  16.64  11.34
# 223  2020/11/30  104.41  137.89  123.53  79.81  114.64  12.08  16.59  11.49
# 224  2020/12/30  103.84  139.41  126.20  80.96  116.73  12.40  16.96  11.91
# 225   2021/1/29  103.69  141.49  126.23  81.51  116.97  12.51  16.97  12.18
#
# ...

# %%
df.USD.plot()

# %%
df.USD.rolling(24).mean().plot()

# %%
df.USD.plot.hist()

# %%
df_diff1 = df.USD.diff().dropna()

# %%
df_diff1.plot.hist()

# %% [markdown]
# # update
